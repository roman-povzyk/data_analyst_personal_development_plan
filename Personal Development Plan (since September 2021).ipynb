# %% [markdown]
# # Персональний план розвитку на час випробовувального періоду (вересень – листопад 2021)

# %% [markdown]
# ## Курси, які планую пройти:
#
# * «A/B Testing» from Google (https://www.udacity.com/course/ab-testing--ud257), 65%.
#
# * «Основи статистики. Частина 2» (https://stepik.org/course/524/promo).
#
# * «Основи статистики. Частина 3» (https://stepik.org/course/2152/promo).
#
# * «Python для Data Science» (https://robotdreams.cc/course/t1-python-for-big-data), у процесі (5/15).
#
# * «Microsoft Power BI Desktop for Business Intelligence» (https://www.udemy.com/course/microsoft-power-bi-up-running-with-power-bi-desktop/).

# %% [markdown]
# ## Книги, які планую прочитати:
#
# * «Говори на мові діаграм», Джин Желязни (61%).

# %% [markdown]
# ## Лекції, які планую прослухати:
#
# * «Історія додатку, у якого аналізували лише дві метрики» (https://www.youtube.com/watch?v=FwU6sQhlWkI).
# * «Активація, або як не дати користувачу піти» (https://www.youtube.com/watch?v=spTbnPq92Ao).
# * «Довготермінове утримання в іграх» (https://www.youtube.com/watch?v=rwhSR8KMjro).
# * «З новим туторіалом!» (https://www.youtube.com/watch?v=8_TFen95-2s).
# * «Player to Payer: покращуємо конверсію у платіж у F2P-грі» (https://www.youtube.com/watch?v=crVTDEcgsmA).
# * «Реклама в іграх: як вона працює і як зробити її кращою» (https://www.youtube.com/watch?v=fp50NNPogvc).
# * «Lifetime и LTV: обрахування, покращення, застосування» (https://www.youtube.com/watch?v=6s_Kq1Pw-zE).
# * «Детальний аналіз змін у грі» (https://www.youtube.com/watch?v=6ZDmcb3P_KE).
# * «Ціноутворення у F2P-іграх і SaaS-системах» (https://www.youtube.com/watch?v=o-zRq8sfn9Y).
# * «Економіка онлайн-ігор» (https://www.youtube.com/watch?v=PnRYpWsfozI).
# * «Ігри жанру match3: як розробити таку гру» (https://www.youtube.com/watch?v=NCZ9Y0Txfr8).
# * «Ігри жанру social casino: як спіймати вдачу» (https://www.youtube.com/watch?v=H6Vgd_YTzi0).
# * «Як вижити у світі ігор жанру Survival» (https://www.youtube.com/watch?v=xoVXMU6htH4).

# %% [markdown]
# ## Посилання, які потрібно освоїти:
#
# 1. 100 корисних посилань для ігрових аналітиків (https://www.devtodev.com/education/articles/ru/139/100-poleznih-ssilok-dlya-igrovih-analitikov)

# %% [markdown]
# ![1.jpg](attachment:1.jpg)

# %% [markdown]
# # Пройдені курси / прочитані книги / переглянуті лекції протягом випробовувального періоду (вересень – листопад 2021)

# %% [markdown]
# ## Пройдені курси:
# 1. «Ігрова аналітика: від основ, до просунутих методів» (https://www.devtodev.com/education/online-course/game-analytics-basics-rus), сертифікат тут: https://www.devtodev.com/education/online-course/certificate/lZoa0al_slW3paGxOWfx8Q.
# 2. «AB-тести в іграх: частина 1» (https://www.devtodev.com/education/online-course/ab-tests-from-a-to-b-part1/), сертифікат тут: https://www.devtodev.com/education/online-course/certificate/k5ka0al_slW3paG3PWf28A/.
# 3. «AB-тести в іграх: частина 2» (https://www.devtodev.com/education/online-course/ab-tests-from-a-to-b-part2/), сертифікат тут: https://www.devtodev.com/education/online-course/certificate/k5kZ0al_slW3paOyPm_68g/.
# 4. «AB-тести в іграх: частина 3» (https://www.devtodev.com/education/online-course/ab-tests-from-a-to-b-part3/), сертифікат тут: https://www.devtodev.com/education/online-course/certificate/k5kY0al_slW3paO1NGny8A.
# 5. «Power BI» від Laba (https://l-a-b-a.com/lecture/show/331).
# 6. «Просунутий Power BI» від Laba (https://l-a-b-a.com/lecture/558-prodvinutyj-power-bi).
# 7. «SQL для бізнес-аналізу» (https://data-b-i.com/uk), тут код: https://github.com/romanpovzyk/sql_for_business_analytics.
# 8.  «Рекламна монетизація: теорія та практика» (https://www.devtodev.com/education/online-course/ad-monetization), сертифікат тут: https://www.devtodev.com/education/online-course/certificate/k58a0al_slW3paaxPGzw9g.
# 9. «Основи статистики» (https://stepik.org/course/76/promo), сертифікат тут: https://stepik.org/cert/1104057.
# 10. «Liveops у проєктах: як оперувати free-to-play проєктами» (https://www.devtodev.com/education/online-course/liveops-in-games), сертифікат тут: https://www.devtodev.com/education/online-course/certificate/npQa0al_slW3paSwNGzw9w/.
# 11. «Маркетинг мобільних ігор: базовий курс» (https://www.devtodev.com/education/online-course/mobile-game-marketing-basics), сертифікат тут: https://www.devtodev.com/education/online-course/certificate/n5wa0al_slS-pa-1OGnw8Q.
# 12. «Психологія у геймдеві» (https://www.devtodev.com/education/online-course/psychology-in-gamedev), сертифікат тут: https://www.devtodev.com/education/online-course/certificate/lYsa0al_slS-paSxP2zy8w.
# 13. «Геймдизайн-документація» (https://www.devtodev.com/education/online-course/gdd-basic-course), сертифікат тут: https://www.devtodev.com/education/online-course/certificate/lZ9v0al_slS-paC3OGf09g/.

# %% [markdown]
# ## Прочитані книги:
# 1. «Сімпсони та їхні математичні секрети», Саймон Сінгх.
# 2. «Як брехати з допомогою статистики», Дарелл Хафф.
# 3. «Гола статистика. Найцікавіша книга про найнуднішу науку», Чарльз Уїлан.
# 4. «Революція, яка змінила те, як ми живемо, працюємо та думаємо», Віктор Майер-Шенбергер, Кеннет Кук'єр.
# 5. «Приборкання великих даних. Як видобувати знання з масивів інформації з допомогою глибокої аналітики», Білл Френкс.
# 6. «Статистика. Базовий курс в коміксах», Грейді Клей.
# 7. «Наука про дані. Базовий курс», Брендан Тірні, Джон Келлегер.

# %% [markdown]
# ## Прослухані лекції:
# 1. «Чому ми весь час говоримо про LTV?» від Андрія Кароля (внутрішня лекція).
# 2. «Способи швидкої перевірки продуктових гіпотез без розробки» від Андрія Кароля (внутрішня лекція).
# 3. «Основні метрики мобільних додатків» (https://www.youtube.com/watch?v=fdsvrDX6Azs).

# %% [markdown]
# ![2.jpg](attachment:2.jpg)

# %% [markdown]
# # Пройдені курси / прочитані книги / переглянуті лекції (травень – серпень 2021)

# %% [markdown]
# ## Прочитані книги:
# 1. «Роман з Data Science», Роман Зиков
# 2. «Data Science для кар'єриста», Жаклін Ноліс, Емілі Робінсон
# 3. «Практична статистика для спеціалістів Data Science. 50 важливих понять», Пітер Брюс, Ендрю Брюс
# 4. «Data Science. Інсайдерська інформація для новачків», Кеті О'Ніл, Рейчел Шатт
# 5. «Реальність під питанням. Чому ігри роблять нас краще і як вони можуть змінити світ», Джейн Мак-Гонігал

# %% [markdown]
# ## Пройдені курси:
#
# Python:
# * «Python programming» from Beetroot Academy (https://beetroot.academy/courses/online/python).
# * «Complete Python Developer in 2021: Zero to Mastery» (https://www.udemy.com/course/complete-python-developer-zero-to-mastery/).
# * Kaggle: Python (https://www.kaggle.com/learn/python).
#
# SQL:
# * Kaggle: Intro to SQL (https://www.kaggle.com/learn/intro-to-sql).
# * «The Complete SQL Bootcamp» (https://www.udemy.com/course/the-complete-sql-bootcamp/).
# * «SQL and PostgreSQL: The Complete Developer's Guide» (https://www.udemy.com/course/sql-and-postgresql/).
#
# Tableau:
# * «Tableau 10 Essential Training» (https://www.linkedin.com/learning/tableau-10-essential-training).
#
# Data Science:
# * «Complete Machine Learning and Data Science: Zero to Mastery» (https://www.udemy.com/course/complete-machine-learning-and-data-science-zero-to-mastery).
# * Kaggle: Pandas (https://www.kaggle.com/learn/pandas), Intro to Machine Learning (https://www.kaggle.com/learn/intro-to-machine-learning), Data Visualization (https://www.kaggle.com/learn/data-visualization), Data Cleaning (https://www.kaggle.com/learn/data-cleaning),
# * Datacamp: Introduction to Data Science in Python, Data Types for Data Science in Python.

# %% [markdown]
# ![3.jpg](attachment:3.jpg)

# %% [markdown]
# # Поради від Володимира Бутка, Software Engineer at EPAM Systems:
# * The Data Science Course 2021: Complete Data Science Bootcamp (https://www.udemy.com/course/the-data-science-course-complete-data-science-bootcamp/)
# * Machine Learning A-Z™: Hands-On Python & R In Data Science (https://www.udemy.com/course/machinelearning/)
# * Deep Learning A-Z™: Hands-On Artificial Neural Networks (https://www.udemy.com/course/deeplearning/)
# * A Complete Guide on TensorFlow 2.0 using Keras API (https://www.udemy.com/course/tensorflow-2/)
# * PyTorch for Deep Learning with Python Bootcamp (https://www.udemy.com/course/pytorch-for-deep-learning-with-python-bootcamp/)
# * Книга і репозиторій: Hands-on Machine Learning with Scikit-Learn, Keras and TensorFlow (https://github.com/ageron/handson-ml2)
# * Podcast SuperDataScience (https://www.superdatascience.com/podcast)
# * Towards Data Science (https://towardsdatascience.com/)
# * 17 types of similarity and dissimilarity measures used in data science (https://towardsdatascience.com/17-types-of-similarity-and-dissimilarity-measures-used-in-data-science-3eb914d2681)
# * NumPy Basics Cheat Sheet (2021) (https://towardsdatascience.com/numpy-basics-cheat-sheet-2021-python-for-data-science-89c483773880)
# *  Harvard University offers 7 online Data Science courses for free (https://content.techgig.com/harvard-university-offers-7-online-data-science-courses-for-free/articleshow/81749501.cms)
# * Data-Science-For-Beginners (https://github.com/microsoft/Data-Science-For-Beginners).
# * ML-For-Beginners (https://github.com/microsoft/ML-For-Beginners).

# %% [markdown]
# # Підглянуте в інших джерелах та у колег:
# * Професійна сертифікація «Аналіз даних від Google» (https://www.coursera.org/professional-certificates/google-data-analytics).
# * Математика у геймдизайні (https://www.devtodev.com/education/online-course/mathematics-in-game-design).
# * Психологія у геймдизайні (https://www.devtodev.com/education/online-course/psychology-in-gamedev).

# %% [markdown]
# ![Screenshot_1.png](attachment:Screenshot_1.png)
